# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %% [markdown]
# ##Indexing
# note: paste the path of template.html file when asked.
#
# /content/drive/Shared drives/TaiwanNCCU TD/gIndex/template.html

# %%
import time
# %cd "/content/drive/Shared drives/TaiwanNCCU TD/gIndex"
time.sleep(1)
sourcePath = "/content/drive/My Drive" #@param {type:'string'}
outputfileName = "Driveindex" #@param {type:'string'}
# outputfileName = "/content/drive/Shared drives/TaiwanNCCU TD/gIndex/" + outputfileName
# !python2 "/content/drive/Shared drives/TaiwanNCCU TD/gIndex/gdriveIndexing.py" '$sourcePath' '$outputfileName'
# Out:
# /content/drive/Shared drives/TaiwanNCCU TD/gIndex
# Copy and paste the path of template.html(available in gIndex folder):    /content/drive/Shared drives/TaiwanNCCU TD/gIndex/template.html
# Processing....
# Traceback (most recent call last):
#   File "/content/drive/Shared drives/TaiwanNCCU TD/gIndex/gdriveIndexing.py", line 129, in <module>
#     generateDirArray(pathToIndex)
#   File "/content/drive/Shared drives/TaiwanNCCU TD/gIndex/gdriveIndexing.py", line 31, in generateDirArray
#     for currentDir, dirs, files in os.walk(dirToScan):
#   File "/usr/lib/python2.7/os.py", line 296, in walk
#     for x in walk(new_path, topdown, onerror, followlinks):
#   File "/usr/lib/python2.7/os.py", line 296, in walk
#     for x in walk(new_path, topdown, onerror, followlinks):
#   File "/usr/lib/python2.7/os.py", line 296, in walk
#     for x in walk(new_path, topdown, onerror, followlinks):
#   File "/usr/lib/python2.7/os.py", line 296, in walk
# ...

# %%
# !ls drive
# Out:
# 'My Drive'  'Shared drives'

# %%
import time
# %cd "/content/drive/My Drive/gIndex"
time.sleep(1)
sourcePath = "/" #@param {type:'string'}
outputfileName = "driveindex.html" #@param {type:'string'}
outputfileName = "/content/drive/My Drive/gIndex/" + outputfileName
# !python2 "/content/drive/My Drive/gIndex/gdriveIndexing.py" '$sourcePath' '$outputfileName'
